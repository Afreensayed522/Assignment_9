# %%
import pandas as pd
df1=pd.read_excel(r"D:\Trainee\afreen Assignments\apple\afreena3\friend_names.xlsx")
df1
# Out:
#    friend name        quality
# 0     vasanthi      sensitive
# 1     chandana          funny
# 2  sindhupriya          anger
# 3      tejasri        selfish
# 4         rani  simple minded
# 5         vani       immeture
# 6       anusha          moody
# 7     gayathri      sensitive
# 8      lakshmi          funny
# 9       ayesha       immeture

# %%
import pandas as pd
df1=pd.read_csv(r"D:\Trainee\afreen Assignments\apple\afreena4\Friendsnames.csv")
df1
# Out:
#    Friendsname            Quality
# 0  vasanthi            sensitive
# 1  chandana          funny
# 2  gayathri                 anger
# 3  anusha                 selfish
# 4  rani             simple minded
# 5  pavani                immeture
# 6  sidhupriya        funny
# 7  tejasri              sensitive
# 8  ayesha             intelligent
# 9  laskhmi               immeture

# %%
df1[df1["Quality"]=="intelligent"]
# Out:
#    Friendsname          Quality
# 8  ayesha           intelligent

# %%
df1[df1['Quality']=='selfish']
# Out:
#    Friendsname      Quality
# 3  anusha           selfish

# %%
df1[df1["Quality"]=="funny"]
# Out:
# Empty DataFrame
# Columns: [Friendsname    , Quality]
# Index: []

# %%
import pandas as pd
df2=pd.read_excel(r"D:\Trainee\afreen Assignments\apple\afreena3\familymember_names.xlsx")
df2
# Out:
#        family member name      relation
# 0       sd.mukharam pasha        father
# 1           sd.ameerunisa        mother
# 2                sd.imran  youngbrother
# 3                sd.irfan  elderbrother
# 4              abdul bari         uncle
# 5      abdul sharifunnisa          aunt
# 6             abdul vahed       brother
# 7              abdul ayub       brother
# 8            abdul javeed       brother
# 9  abdul neelofar sultana        sister

# %%
df2[(df2["relation"]=="brother") | (df2["relation"]=="sister")]
# Out:
#        family member name relation
# 6             abdul vahed  brother
# 7              abdul ayub  brother
# 8            abdul javeed  brother
# 9  abdul neelofar sultana   sister

# %%
df2[(df2["relation"]=="father") | (df2["relation"]=="mother")]
# Out:
#   family member name relation
# 0  sd.mukharam pasha   father
# 1      sd.ameerunisa   mother

# %%
lst=["mother","father"]
df2[~df2['relation'].isin(lst)]
# Out:
#        family member name      relation
# 2                sd.imran  youngbrother
# 3                sd.irfan  elderbrother
# 4              abdul bari         uncle
# 5      abdul sharifunnisa          aunt
# 6             abdul vahed       brother
# 7              abdul ayub       brother
# 8            abdul javeed       brother
# 9  abdul neelofar sultana        sister

# %%
df2[(df2['relation']!='brother')]
# Out:
#        family member name      relation
# 0       sd.mukharam pasha        father
# 1           sd.ameerunisa        mother
# 2                sd.imran  youngbrother
# 3                sd.irfan  elderbrother
# 4              abdul bari         uncle
# 5      abdul sharifunnisa          aunt
# 9  abdul neelofar sultana        sister

# %%
df2[(df2["relation"]=="father") | (df2["relation"]=="mother") | (df2["relation"]=="brother")]
# Out:
#   family member name relation
# 0  sd.mukharam pasha   father
# 1      sd.ameerunisa   mother
# 6        abdul vahed  brother
# 7         abdul ayub  brother
# 8       abdul javeed  brother

# %%
lst=["mother","father","brother"]
df2[df2['relation'].isin(lst)]
# Out:
#   family member name relation
# 0  sd.mukharam pasha   father
# 1      sd.ameerunisa   mother
# 6        abdul vahed  brother
# 7         abdul ayub  brother
# 8       abdul javeed  brother

# %%
import pandas as pd
df3=pd.read_excel(r"D:\Trainee\afreen Assignments\apple\afreena4\vegfoodnames.xlsx")
df3
# Out:
#          items  taste
# 0      tomatto  curry
# 1       banana    fry
# 2         aloo  curry
# 3        puree  soups
# 4        broth  soups
# 5       carrot    fry
# 6  cauliflower  curry
# 7      cabbage    fry
# 8      brinjal  curry

# %%
df3[(df3["taste"]=='soups')]
# Out:
#    items  taste
# 3  puree  soups
# 4  broth  soups

# %%
df3[(df3['taste']=='fry')]
# Out:
#      items taste
# 1   banana   fry
# 5   carrot   fry
# 7  cabbage   fry

# %%
df3[df3["taste"]=="curry"]
# Out:
#          items  taste
# 0      tomatto  curry
# 2         aloo  curry
# 6  cauliflower  curry
# 8      brinjal  curry

# %%
lst=['soups','fry']
df3[~df3['taste'].isin(lst)]
# Out:
#          items  taste
# 0      tomatto  curry
# 2         aloo  curry
# 6  cauliflower  curry
# 8      brinjal  curry

# %%
lst=['soups','fry']
df3[~df3['taste'].isin(lst)]
# Out:
#          items  taste
# 0      tomatto  curry
# 2         aloo  curry
# 6  cauliflower  curry
# 8      brinjal  curry

# %%
df3[(df3['taste']=='soups') | (df3['taste']=='fry')]
# Out:
#      items  taste
# 1   banana    fry
# 3    puree  soups
# 4    broth  soups
# 5   carrot    fry
# 7  cabbage    fry

# %%
import pandas as pd
df4=pd.read_excel(r"D:\Trainee\afreen Assignments\apple\afreena4\nonvegitems.xlsx")
df4
# Out:
#     items       taste
# 0  chiken       curry
# 1  mutton       curry
# 2  mutton         fry
# 3  chiken         fry
# 4    fish       curry
# 5  mutton      khawab
# 6  chiken  manchuriya
# 7    fish         fry
# 8     egg     biryani

# %%
df4[(df4['items']=='chiken')]
# Out:
#     items       taste
# 0  chiken       curry
# 3  chiken         fry
# 6  chiken  manchuriya

# %%
df4[(df4['items']=='mutton')]
# Out:
#     items   taste
# 1  mutton   curry
# 2  mutton     fry
# 5  mutton  khawab

# %%
df4[(df4['taste']=='fry')]
# Out:
#     items taste
# 2  mutton   fry
# 3  chiken   fry
# 7    fish   fry

# %%
lst=['fry','chiken']
df4[~(df4['taste'].isin(lst)) & ~(df4['items'].isin(lst))]
# Out:
#     items    taste
# 1  mutton    curry
# 4    fish    curry
# 5  mutton   khawab
# 8     egg  biryani

# %%
df4[(df4['taste']=='fry') | (df4['items']=='mutton')]
# Out:
#     items   taste
# 1  mutton   curry
# 2  mutton     fry
# 3  chiken     fry
# 5  mutton  khawab
# 7    fish     fry

# %%
import pandas as pd
df5=pd.read_excel(r"D:\Trainee\afreen Assignments\apple\afreena4\monthnames.xlsx")
df5
# Out:
#         month  season
# 0     january  summer
# 1    february  summer
# 2       march  summer
# 3       april  automn
# 4         may  automn
# 5        june  spring
# 6        july  spring
# 7       agust  spring
# 8   september   rainy
# 9     october   rainy
# 10   november  winter
# 11   december  winter

# %%
df5[(df5['season']=='winter')]
# Out:
#        month  season
# 10  november  winter
# 11  december  winter

# %%
df5[(df5['season']=='summer')]
# Out:
#       month  season
# 0   january  summer
# 1  february  summer
# 2     march  summer

# %%
df5[(df5['season']=='rainy')]
# Out:
#        month season
# 8  september  rainy
# 9    october  rainy

# %%
df5[(df5['season']=='winter') | (df5['season']=='summer')]
# Out:
#        month  season
# 0    january  summer
# 1   february  summer
# 2      march  summer
# 10  november  winter
# 11  december  winter

# %%
lst=['summer','rainy']
df5[~(df5['season'].isin(lst))]
# Out:
#        month  season
# 3      april  automn
# 4        may  automn
# 5       june  spring
# 6       july  spring
# 7      agust  spring
# 10  november  winter
# 11  december  winter

# %%
df5[(df5['season']=='winter') | (df5['season']=='rainy')]
# Out:
#         month  season
# 8   september   rainy
# 9     october   rainy
# 10   november  winter
# 11   december  winter

# %%
import pandas as pd
df6=pd.read_excel(r"D:\Trainee\afreen Assignments\apple\afreena4\flowernames.xlsx")
df6
# Out:
#    colour flower_name_in_english  flower_name_in_telugu flower_name_in_hindi
# 0     red               hibiscus                mandara          gulabkaphul
# 1     red           Red Marigold             bantipuvvu           gandkaphul
# 2     red            Lily Flower                  lilly                lilly
# 3     red          Red Sunflower  prodduthirugudu puvvu       laalsurajmukhi
# 4   white              whiterose            tellagulabi           safedgulab
# 5   white                  lotus            tamarapuvvu                kamal
# 6   white                jasmine              malepuvvu                 bela
# 7   white                  lilly                  lilly                lilly
# 8    pink          chrysanthemum               chamanti             chamanti
# 9    pink                   rose            gulabipuvvu                gulab
# 10   pink               hibiscus                mandara          gulabkaphul

# %%
df6[(df6['colour']=='red')]
# Out:
#   colour flower_name_in_english  flower_name_in_telugu flower_name_in_hindi
# 0    red               hibiscus                mandara          gulabkaphul
# 1    red           Red Marigold             bantipuvvu           gandkaphul
# 2    red            Lily Flower                  lilly                lilly
# 3    red          Red Sunflower  prodduthirugudu puvvu       laalsurajmukhi

# %%
df6[(df6['colour']=='white')]
# Out:
#   colour flower_name_in_english flower_name_in_telugu flower_name_in_hindi
# 4  white              whiterose           tellagulabi           safedgulab
# 5  white                  lotus           tamarapuvvu                kamal
# 6  white                jasmine             malepuvvu                 bela
# 7  white                  lilly                 lilly                lilly

# %%
df6[(df6['colour']=='pink')]
# Out:
#    colour flower_name_in_english flower_name_in_telugu flower_name_in_hindi
# 8    pink          chrysanthemum              chamanti             chamanti
# 9    pink                   rose           gulabipuvvu                gulab
# 10   pink               hibiscus               mandara          gulabkaphul

# %%
df6[(df6['colour']=='red') | (df6['colour']=='pink')]
# Out:
#    colour flower_name_in_english  flower_name_in_telugu flower_name_in_hindi
# 0     red               hibiscus                mandara          gulabkaphul
# 1     red           Red Marigold             bantipuvvu           gandkaphul
# 2     red            Lily Flower                  lilly                lilly
# 3     red          Red Sunflower  prodduthirugudu puvvu       laalsurajmukhi
# 8    pink          chrysanthemum               chamanti             chamanti
# 9    pink                   rose            gulabipuvvu                gulab
# 10   pink               hibiscus                mandara          gulabkaphul

# %%
lst=['red','white']
df6[~(df6['colour'].isin(lst))]
# Out:
#    colour flower_name_in_english flower_name_in_telugu flower_name_in_hindi
# 8    pink          chrysanthemum              chamanti             chamanti
# 9    pink                   rose           gulabipuvvu                gulab
# 10   pink               hibiscus               mandara          gulabkaphul

# %%
df6[(df6['colour']=='red') | (df6['colour']=='pink')]
# Out:
#    colour flower_name_in_english  flower_name_in_telugu flower_name_in_hindi
# 0     red               hibiscus                mandara          gulabkaphul
# 1     red           Red Marigold             bantipuvvu           gandkaphul
# 2     red            Lily Flower                  lilly                lilly
# 3     red          Red Sunflower  prodduthirugudu puvvu       laalsurajmukhi
# 8    pink          chrysanthemum               chamanti             chamanti
# 9    pink                   rose            gulabipuvvu                gulab
# 10   pink               hibiscus                mandara          gulabkaphul
